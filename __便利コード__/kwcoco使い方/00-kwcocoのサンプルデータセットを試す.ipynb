# %%
! pip install kwcoco kwplot

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import kwcoco, kwplot
import random

coco = kwcoco.CocoDataset.demo('photos')
# coco = kwcoco.CocoDataset.demo('shapes')
# coco = kwcoco.CocoDataset.demo('vidshapes')
# coco = kwcoco.CocoDataset.demo('vidshapes8 ')
# coco = kwcoco.CocoDataset.demo('shapes8 ')
# coco = kwcoco.CocoDataset.demo('shapes8-msi ')
# coco = kwcoco.CocoDataset.demo('shapes8-frames1-speed0.2-msi ')

gids = list(coco.imgs.keys())
cids = list(coco.cats.keys())
aids = list(coco.anns.keys())

sample_imgId = random.choice(gids)

kwplot.autompl()
coco.show_image(gid=sample_imgId)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# loading image
# loaded image
# <Axes: title={'center': 'gid=2 carl.jpg'}>
