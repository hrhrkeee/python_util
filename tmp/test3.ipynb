# %%
# 0~1km: 400
# ~10km: 40/400m
# 10km~: 40/350m

# 低速: 0~10km/h : +40/45s
# 深夜: 2400~0600 : all *1.5
# ピーク: 
    # 0600~0930 and 2000~2400 : all *1.3


# 入力
# 時間 走行距離[m]


import sys
import numpy as np
import pandas as pd
from datetime import timedelta

def calc_speed(distance, hour) -> int:
    # distance : [m]
    if hour == 0:  return 0
    else:          return distance / hour

def calc_timedelta(time1:np.datetime64, time2:np.datetime64, type="s") -> int:
    return (time1 - time2) / np.timedelta64(1, type)


def main(lines):
    distance_meter = 0
    low_speed_meter = 0
    fares_meter = 0

    distance_tmp = 0

    dict_data = [dict([["time", pd.Timestamp(s.split()[0])], ["distance", float(s.split()[1])]])  for s in lines]
    df = pd.DataFrame(dict_data)

    for i in range(1, len(lines)):
        option = 1.0

        record_1 = df.iloc[i-1]
        record_2 = df.iloc[i]

        diff_time = calc_timedelta(record_2["time"], record_1["time"], type="s")
        distance_meter += record_2["distance"] # [m]
        speed = calc_speed(record_2["distance"]/1000, diff_time/3600) # [km/h]

        
        # 時間帯による加算
        # 深夜
        if record_1["time"].hour >= 0 and record_1["time"].hour <= 6:
            option = 1.5

        # ピーク
        if record_1["time"].hour >= 6 and (record_1["time"].hour*60 + record_1["time"].minute) <= 570:
            option = 1.3
        elif record_1["time"].hour >= 20 and record_1["time"].hour <= 24:
            option = 1.3


        # 走行距離による加算
        distance_tmp += record_2["distance"]
        if distance_meter <= 1000:
            fares_meter = 400 * option
            distance_tmp = 0
        elif 1000 < distance_meter <= 1000 + 400*22:
            if distance_tmp-record_2["distance"] == 0:
                fares_meter += 40 * option
            if distance_tmp-record_2["distance"] >= 400:
                distance_tmp = 0
        else:
            if distance_tmp-record_2["distance"] == 0:
                fares_meter += 40 * option
            if distance_tmp-record_2["distance"] >= 350:
                distance_tmp = 0

        # 速度による加算
        if speed <= 10:
            low_speed_meter += diff_time
            if low_speed_meter >= 45:
                fares_meter += 40 * option
                low_speed_meter = low_speed_meter - 45
            continue

    print(int(fares_meter))

    return 


if __name__ == '__main__':
    # lines = ["3", "3 1 5"]
    lines = ['12:00:00.000 0.0', '12:00:05.000 50.0']

    lines = [
        "12:00:00.000 0.0",
        "12:00:05.000 50.0",
        "12:00:10.000 50.0",
        "12:00:15.000 50.0",
        "12:00:20.000 50.0",
        "12:00:25.000 50.0",
        "12:00:30.000 50.0",
        "12:00:35.000 50.0",
        "12:00:40.000 50.0",
        "12:00:45.000 50.0",
        "12:00:50.000 50.0",
        "12:00:55.000 50.0",
        "12:01:00.000 50.0",
        "12:01:05.000 50.0",
        "12:01:10.000 50.0",
        "12:01:15.000 50.0",
        "12:01:20.000 50.0",
        "12:01:25.000 50.0",
        "12:01:30.000 50.0",
        "12:01:35.000 50.0",
        "12:01:40.000 50.0",
        "12:01:45.000 50.0",
        "12:01:50.000 50.0",
        "12:01:55.000 50.0",
        "12:02:00.000 50.0",
        "12:02:05.000 50.0",
        "12:02:10.000 50.0",
        "12:02:15.000 50.0",
        "12:02:20.000 50.0",
        "12:02:25.000 50.0",
        "12:02:30.000 50.0",
        "12:02:35.000 50.0",
        "12:02:40.000 50.0",
        "12:02:45.000 50.0",
        "12:02:50.000 50.0",
